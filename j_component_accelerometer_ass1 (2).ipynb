# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
df=pd.read_csv('/content/drive/MyDrive/accelerometer.csv')

# %%
df.describe
# Out:
# <bound method NDFrame.describe of         wconfid  pctid      x      y      z
# 0             1     20  1.004  0.090 -0.125
# 1             1     20  1.004 -0.043 -0.125
# 2             1     20  0.969  0.090 -0.121
# 3             1     20  0.973 -0.012 -0.137
# 4             1     20  1.000 -0.016 -0.121
# ...         ...    ...    ...    ...    ...
# 152995        3    100  1.051  0.090 -0.262
# 152996        3    100  0.918  0.039 -0.129
# 152997        3    100  1.156 -0.094 -0.227
# 152998        3    100  0.934  0.203 -0.172
# 152999        3    100  1.199 -0.176  0.109
#
# [153000 rows x 5 columns]>

# %%
from matplotlib import pyplot as p
y=df['x']
x=df['wconfid']
p.plot(x,y,'g')
p.xlabel('wconfid')
p.ylabel('accelerometer y value')
# Out:
# Text(0, 0.5, 'accelerometer y value')

# %%
from matplotlib import pyplot as p
y=df['x']
x=df['wconfid']
p.scatter(x,y,)
p.xlabel('wconfid')
p.ylabel('accelerometer y value')
# Out:
# Text(0, 0.5, 'accelerometer y value')

# %%
from matplotlib import pyplot as p
y=df['x']
x=df['pctid']
p.plot(x,y,'b')
p.xlabel('pctid')
p.ylabel('accelometer x value')
# Out:
# Text(0, 0.5, 'accelometer x value')

# %%
from matplotlib import pyplot as p
y=df['x']
x=df['pctid']
p.scatter(x,y)
p.xlabel('pctid')
p.ylabel('accelometer x value')
# Out:
# Text(0, 0.5, 'accelometer x value')

# %%
from matplotlib import pyplot as p
y=df['y']
x=df['wconfid']
p.plot(x,y,'g')
p.xlabel('wconfid')
p.ylabel('accelometer y value')
# Out:
# Text(0, 0.5, 'accelometer y value')

# %%
from matplotlib import pyplot as p
y=df['y']
x=df['wconfid']
p.scatter(x,y,color='g')
p.xlabel('wconfid')
p.ylabel('accelometer y value')
# Out:
# Text(0, 0.5, 'accelometer y value')

# %%
from matplotlib import pyplot as p
y=df['y']
x=df['pctid']
p.plot(x,y,'r')
p.xlabel('pctid')
p.ylabel('accelometer x value')
# Out:
# Text(0, 0.5, 'accelometer x value')

# %%
from matplotlib import pyplot as p
y=df['y']
x=df['pctid']
p.scatter(x,y,color='b')
p.xlabel('pctid')
p.ylabel('accelometer x value')
# Out:
# Text(0, 0.5, 'accelometer x value')

# %%
from matplotlib import pyplot as p
y=df['z']
x=df['wconfid']
p.plot(x,y,'r')
p.xlabel('wconfid')
p.ylabel('accelometer z value')
# Out:
# Text(0, 0.5, 'accelometer z value')

# %%
from matplotlib import pyplot as p
y=df['z']
x=df['wconfid']
p.scatter(x,y,color='g')
p.xlabel('wconfid')
p.ylabel('accelometer z value')
# Out:
# Text(0, 0.5, 'accelometer z value')

# %%
from matplotlib import pyplot as p
y=df['z']
x=df['pctid']
p.plot(x,y,'b')
p.xlabel('pctid')
p.ylabel('accelometer z value')
# Out:
# Text(0, 0.5, 'accelometer z value')

# %%
from matplotlib import pyplot as p
y=df['z']
x=df['pctid']
p.scatter(x,y,color='g')
p.xlabel('pctid')
p.ylabel('accelometer z value')
# Out:
# Text(0, 0.5, 'accelometer z value')
